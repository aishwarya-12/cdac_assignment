# %%
import pandas as pd
import numpy as np

# %%
#Simple Random Sampling
df_2015 = pd.read_csv("marathon_results_2015.csv")
df_2016 =pd.read_csv("marathon_results_2016.csv")
df_2017 = pd.read_csv("marathon_results_2017.csv")

df = pd.concat([df_2015, df_2016, df_2017])
original_row_count = len(df)

# %%
sample_df = df.sample(frac = 0.1, random_state = 42)
sample_row_count = len(sample_df)

print(df.head)
print(sample_df.head())
# Out:
# <bound method NDFrame.head of        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 0             0.0      3            Desisa, Lelisa   25   M          Ambo
# 1             1.0      4     Tsegay, Yemane Adhane   30   M   Addis Ababa
# 2             2.0      8            Chebet, Wilson   29   M      Marakwet
# 3             3.0     11          Kipyego, Bernard   28   M       Eldoret
# 4             4.0     10             Korir, Wesley   32   M        Kitale
# ...           ...    ...                       ...  ...  ..           ...
# 26405     26405.0  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 26406     26406.0  25178        Avelino, Andrew R.   25   M  Fayetteville
# 26407     26407.0  27086           Hantel, Johanna   57   F       Malvern
# 26408     26408.0  25268              Reilly, Bill   64   M      New York
# 26409     26409.0  25266             Rigsby, Scott   48   M    Alpharetta
#
# ...

# %%
print(original_row_count)
print(sample_row_count)
# Out:
# 79638
# 7964

# %%
#Systematic Random Sampling
sample_df1 = df.iloc[::7,:]
sample_row_count1 = len(sample_df1)

print(df.head())
print(sample_df1.head())
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# ...

# %%
print(original_row_count)
print(sample_row_count1)
# Out:
# 79638
# 11377

# %%
#Stratified Random Sampling
total_males = len(df[df['M/F'] == 'M'])
total_females = len(df[df['M/F'] == 'F'])

sample_size = int(0.1 * orignal_row_count)
sample_males = int(0.1*total_males)
sample_females = int(0.1 * total_females)
print('Sample Size : ', sample_size, '\n', 'Sample Males : ', sample_males, '\n', 'Sample Females : ', sample_females)
# Out:
# Sample Size :  7963
#  Sample Males :  4348
#  Sample Females :  3615

# %%
#Generate proportionate samples of male and female athletes
male_sample = df[df['M/F'] == 'M'].sample(n=sample_males, random_state = 42)
female_sample = df[df['M/F'] == 'F'].sample(n=sample_females, random_state = 42)
print('Male sample : ', len(male_sample), '\n', 'Female Sample : ', len(female_sample))
# Out:
# Male sample :  4348
#  Female Sample :  3615

# %%
#combine male and female smples into a single sample dataframe
sample_df2 = pd.concat([male_sample, female_sample])
sample_row_count2 = len(sample_df2)
print(df.head())
print('\n', sample_df2.head())
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# ...

# %%
print(orignal_row_count)
print(sample_row_count2)
# Out:
# 79638
# 7963

# %%
print("Number of male athletes in the sample dataframe : ", len(male_sample))
print("number of female athletes in the sample dataframe : ", len(female_sample))
# Out:
# Number of male athletes in the sample dataframe :  4348
# number of female athletes in the sample dataframe :  3615

# %%
#cluster Sampling : Find the unique countries the athletes are from
unique_countries = df['Country'].unique()
num_countries = len(unique_countries)
print("Unique Countries : ", unique_countries, '\n', 'Number of Unique Countries : ', num_countries)
# Out:
# Unique Countries :  ['ETH' 'KEN' 'USA' 'UKR' 'RSA' 'ITA' 'RUS' 'JPN' 'CAN' 'BEL' 'NZL' 'BLR'
#  'AUS' 'GBR' 'CRO' 'ECU' 'GER' 'ESP' 'SWE' 'BRA' 'HKG' 'MEX' 'DEN' 'MAS'
#  'IRL' 'ISL' 'CHI' 'GUA' 'FIN' 'SVK' 'COL' 'SUI' 'CHN' 'AUT' 'NED' 'FRA'
#  'CRC' 'CYP' 'POL' 'NOR' 'KOR' 'POR' 'TPE' 'PER' 'SIN' 'PAN' 'VEN' 'LUX'
#  'CZE' 'VIE' 'MAR' 'BER' 'ROU' 'IND' 'LIE' 'ARG' 'ESA' 'DOM' 'ISR' 'GRE'
#  'SLO' 'LTU' 'URU' 'CAY' 'EST' 'JAM' 'UAE' 'VGB' 'TUR' 'LAT' 'AND' 'OMA'
#  'BAH' 'TRI' 'INA' 'AHO' 'PHI' 'UGA' 'QAT' 'ZIM' 'TWN' 'HON' 'FLK' 'HUN'
#  'JOR' 'ALB' 'SRB' 'PAK' 'BRN' 'BDI' 'EGY' 'THA' 'MLT' 'KSA' 'SMR' 'BUL'
#  'ALG' 'NCA' 'BAR' 'GRN' 'PAR' 'TCA' 'KUW' 'MGL' 'NGR']
#  Number of Unique Countries :  105

# %%
#Ramdomly select half of the countries
np.random.seed(42)
#choice() function in numpy generates a random sample from an array
selected_countries = np.random.choice(unique_countries, size = num_countries//2, replace = False)
#replace = False means do not allow the same country twice or more

print(selected_countries)
# Out:
# ['COL' 'JAM' 'EST' 'IND' 'PAN' 'SMR' 'NGR' 'LUX' 'NZL' 'ETH' 'SWE' 'SUI'
#  'BDI' 'ALG' 'UGA' 'RSA' 'TWN' 'AUT' 'AUS' 'CHI' 'GRN' 'ARG' 'DEN' 'PHI'
#  'SIN' 'BAH' 'ECU' 'TPE' 'KOR' 'BEL' 'ALB' 'BLR' 'MGL' 'QAT' 'FIN' 'ZIM'
#  'ITA' 'URU' 'ESA' 'NOR' 'FRA' 'GER' 'UAE' 'NED' 'JPN' 'PER' 'TUR' 'LAT'
#  'GUA' 'BRA' 'JOR' 'ISL']

# %%
#create a new_dataframe containing all records of the selected countries
sample_df1 = df[df['Country'].isin(selected_countries)]
sample_row_count3 = len(sample_df)
print(df.head(), sample_df.head())
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# ...

# %%
print(original_row_count, sample_row_count3)
# Out:
# 79638 7964
